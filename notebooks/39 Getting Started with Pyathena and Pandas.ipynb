# %%
from pyathena import connect

# %%
import pandas as pd

# %%
conn = connect(
    work_group='primary',
    s3_staging_dir='s3://aiathenaresults/ghactivity/'
)

# %%
pd.read_sql?

# %%
pd.read_sql('SELECT * FROM github_db.ghactivity LIMIT 10', conn)
